# %%
name = input("Enter you name")
print("Hello", name, "!!!!")
# Out:
# Enter you name arti
# Hello arti !!!!

# %%
x, y =input("enter two values").split()
print(x)
print(y)
# Out:
# enter two values 234 234
# 234
# 234

# %%
n = int(input("how many apples"))
print(n)
# Out:
# how many apples 3456
# 3456

# %%
price = float(input("price of an apple:"))
print(price)
# Out:
# price of an apple: 23
# 23.0
